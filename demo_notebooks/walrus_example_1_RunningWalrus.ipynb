# %% [markdown]
# # Running Walrus outside of train.py
#
# Hello! In this demo, we'll walk you how to use the Walrus foundation model outside of our provided training code. While the training code has many features
# and options, this can also make it a bit hard to catch the essentials. That is why this notebook exists. We'll walk you through how to use
# Walrus, primarily in inference here, both with Well formatted data and if you have data you can't force into the Well's format to use our included data utilities.
#
# ## Part 1: Using Walrus with Well-style datasets
#
# Prereqs:
# - Since this is using Well-style datasets, this section assumes you have Well-structured data, likely downloaded into a folder structure matching the one you'd get from downloading [The Well](https://github.com/PolymathicAI/the_well).
# - While this example only covers inference, this is using a 1.3B parameter model, so it is necessary to have either enough RAM if using CPU (slow) or VRAM if using GPU to handle a model of this size.
#
# The Walrus codebase is designed with Well-style datasets in mind. While it is not necessary to use these for Walrus,
# we're going to cover this option first since it's going to be a bit more straightforward.
#
# We're also going to take advantage of [Hydra](https://hydra.cc) to translate between OmegaConf configs and datasets and the pretrained Walrus model.
# Hydra is useful for hierarchical instantiation. It lets us break torch modules into individual component types and define models as a hierarchy
# of modular components that can be swapped out completely for other components.
#
# As a first step, we're just going to download the data. We'll just use wget to pull it from huggingface.

# %%
pwd
# Out:
# '/Users/jarvislam/neural_pde/walrus/demo_notebooks'

# %%
import os

checkpoint_base_path = "./checkpoints/"
config_base_path = "./configs/"
os.makedirs(checkpoint_base_path, exist_ok=True)
os.makedirs(config_base_path, exist_ok=True)

# # And we'll download the weights from huggingface
# !wget  https://huggingface.co/polymathic-ai/walrus/resolve/main/extended_config.yaml \
#     -O {config_base_path}/extended_config.yaml
# # !wget  https://huggingface.co/polymathic-ai/walrus/resolve/main/walrus.pt \
# #     -O {checkpoint_base_path}/walrus.pt

# %%
# !which python3.12
# Out:
# /Users/jarvislam/neural_pde/venv/bin/python3.12

# %%
# %pip uninstall torch torchvision -y

# %%
# !python3.12 -m pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2

# %%
# !python3.12 -m pip install /Users/jarvislam/neural_pde/walrus/.
# Out:
# Processing /Users/jarvislam/neural_pde/walrus
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: einops<0.9,>=0.8 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (0.8.2)
# Requirement already satisfied: h5py<4,>=3.9.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (3.16.0)
# Requirement already satisfied: hydra-core<2,>=1.3 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (1.3.2)
# Requirement already satisfied: imageio<3,>=2.25 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (2.37.3)
# Requirement already satisfied: matplotlib<4,>=3.8 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (3.10.9)
# Requirement already satisfied: numpy==1.26.4 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (1.26.4)
# Requirement already satisfied: pandas==2.2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (2.2.0)
# Requirement already satisfied: plotly<6,>=5.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (5.24.1)
# Collecting the_well @ git+https://github.com/PolymathicAI/the_well.git@master (from the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0)
#   Cloning https://github.com/PolymathicAI/the_well.git (to revision master) to /private/var/folders/bx/fy2w7f4d5k12lqdvb0kmwy300000gn/T/pip-install-i0pkscdx/the-well_9166b151d33f497c99e4dad307d3a720
#   Running command git clone --filter=blob:none --quiet https://github.com/PolymathicAI/the_well.git /private/var/folders/bx/fy2w7f4d5k12lqdvb0kmwy300000gn/T/pip-install-i0pkscdx/the-well_9166b151d33f497c99e4dad307d3a720
#   Resolved https://github.com/PolymathicAI/the_well.git to commit b408b0bfa616ab0e7f2ff243a1c60bd3b5158f56
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: timm<2,>=1.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (1.0.27)
# Requirement already satisfied: torch==2.5.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (0.20.1)
# Requirement already satisfied: torchaudio==2.5.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (2.5.1)
# Requirement already satisfied: torchinfo<2,>=1.8.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (1.8.0)
# Requirement already satisfied: wandb>=0.17.9 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from walrus==1.0.0) (0.27.0)
# Requirement already satisfied: pyyaml>=6.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (6.0.3)
# Requirement already satisfied: fsspec==2024.10.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (2024.10.0)
# Requirement already satisfied: neuraloperator==0.3.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.3.0)
# Requirement already satisfied: omegaconf<3,>=2.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (2.3.0)
# Requirement already satisfied: torch_harmonics<0.7,>=0.6 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.6.3)
# Requirement already satisfied: huggingface-hub in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.16.1)
# Requirement already satisfied: configmypy in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.2.0)
# Requirement already satisfied: pytest in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (9.0.3)
# Requirement already satisfied: black in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (26.5.1)
# Requirement already satisfied: tensorly in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.9.0)
# Requirement already satisfied: tensorly-torch in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.5.0)
# Requirement already satisfied: opt-einsum in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pandas==2.2->walrus==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pandas==2.2->walrus==1.0.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pandas==2.2->walrus==1.0.0) (2026.2)
# Requirement already satisfied: filelock in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (4.15.0)
# Requirement already satisfied: networkx in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (3.1.6)
# Requirement already satisfied: setuptools in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (82.0.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torch==2.5.1->walrus==1.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.5.1->walrus==1.0.0) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from torchvision==0.20.1->walrus==1.0.0) (12.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from hydra-core<2,>=1.3->walrus==1.0.0) (4.9.3)
# Requirement already satisfied: packaging in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from hydra-core<2,>=1.3->walrus==1.0.0) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from matplotlib<4,>=3.8->walrus==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from matplotlib<4,>=3.8->walrus==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from matplotlib<4,>=3.8->walrus==1.0.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from matplotlib<4,>=3.8->walrus==1.0.0) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from matplotlib<4,>=3.8->walrus==1.0.0) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from plotly<6,>=5.0->walrus==1.0.0) (9.1.4)
# Requirement already satisfied: safetensors in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from timm<2,>=1.0->walrus==1.0.0) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2->walrus==1.0.0) (1.17.0)
# Requirement already satisfied: click>=8.2.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (3.1.50)
# Requirement already satisfied: platformdirs in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (7.35.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (2.13.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (2.34.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from wandb>=0.17.9->walrus==1.0.0) (2.60.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.17.9->walrus==1.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.17.9->walrus==1.0.0) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb>=0.17.9->walrus==1.0.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb>=0.17.9->walrus==1.0.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb>=0.17.9->walrus==1.0.0) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb>=0.17.9->walrus==1.0.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb>=0.17.9->walrus==1.0.0) (2026.5.20)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.17.9->walrus==1.0.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.17.9->walrus==1.0.0) (5.0.3)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from black->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from black->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.1.1)
# Requirement already satisfied: pytokens~=0.4.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from black->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.4.1)
# Requirement already satisfied: pytest-mock in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from configmypy->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (3.15.1)
# Requirement already satisfied: ruamel.yaml in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from configmypy->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.19.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (4.67.3)
# Requirement already satisfied: typer>=0.20.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.25.1)
# Requirement already satisfied: anyio in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from jinja2->torch==2.5.1->walrus==1.0.0) (3.0.3)
# Requirement already satisfied: iniconfig>=1.0.1 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pytest->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from pytest->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.6.0)
# Requirement already satisfied: scipy in /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages (from tensorly->neuraloperator==0.3.0->the_well @ git+https://github.com/PolymathicAI/the_well.git@master->the_well[benchmark] @ git+https://github.com/PolymathicAI/the_well.git@master->walrus==1.0.0) (1.17.1)
# Building wheels for collected packages: walrus
#   Building wheel for walrus (pyproject.toml) ... done
#   Created wheel for walrus: filename=walrus-1.0.0-py3-none-any.whl size=124507 sha256=9d606704b204441f0d5a355a5f50795c83f5f9cad0b5e7be1714e35b2e72bbd5
#   Stored in directory: /private/var/folders/bx/fy2w7f4d5k12lqdvb0kmwy300000gn/T/pip-ephem-wheel-cache-ltwad_3i/wheels/bb/32/10/5f6357756362f05fc385fca4bf180520364cbb8629111d0055
# Successfully built walrus
# Installing collected packages: walrus
#   Attempting uninstall: walrus
#     Found existing installation: walrus 1.0.0
#     Uninstalling walrus-1.0.0:
#       Successfully uninstalled walrus-1.0.0
# Successfully installed walrus-1.0.0
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from walrus.data.multidataset import MixedWellDataset
from walrus.data.inflated_dataset import InflatedWellDataset
from walrus.models import IsotropicModel
from walrus.data.well_to_multi_transformer import ChannelsFirstWithTimeFormatter
from hydra.utils import instantiate
from omegaconf import DictConfig, OmegaConf, open_dict
from the_well.data.utils import flatten_field_names
# from walrus.trainer.normalization_strat import (
#     normalize_target,
# )
from the_well.benchmark.metrics import make_video

checkpoint_path = f"{checkpoint_base_path}/walrus.pt"
checkpoint_config_path = f"{config_base_path}/extended_config.yaml"
checkpoint = torch.load(checkpoint_path, map_location="cpu", weights_only=True)["app"]["model"]

# %% [markdown]
# There are a couple key configuration areas since we're using Walrus outside of the training code:
# - **config.data** - Defines the input data configuration used during training this checkpoint.
#     - **config.data.field_index_map_override** - Gives a mapping between physical fields and indices keys in the embedding layer.
# - **config.model** - Defines the structure of the Walrus model itself.
# - **config.trainer.revin** - Tells us what normalization approach to use.
# - **config.trainer.formatter** - Tells us what to use to format the data before feeding it into the model.
#
# We'll start off this process by initializing the data and model. The data size helps us determine the size of the input embedding layer. For ease of use, we'll
# load the full `DataModule` object which has a bit higher overhead compared to loading just the required dataset, but will make the overall process easier.
#
# Since we're using a pretrained checkpoint, we do not need the datamodule to prefetch field information from the data. Instead, we'll be using the
# saved information already in the data config.

# %%
checkpoint["blocks.0.space_mixing.attn_out.weight"]
# Out:
# tensor([[-1.0450e-02, -7.2388e-04,  9.2631e-03,  ..., -1.9939e-02,
#           3.5953e-02,  1.3411e-03],
#         [-6.5673e-03,  1.0659e-02, -9.8656e-03,  ..., -1.0835e-02,
#          -6.1537e-03, -2.2518e-02],
#         [ 3.6665e-04,  1.9734e-02,  2.1300e-02,  ..., -1.0462e-02,
#           1.0675e-02, -2.9784e-03],
#         ...,
#         [-1.8735e-02, -1.8043e-02, -2.1144e-02,  ...,  2.9193e-02,
#          -8.7081e-05,  6.4949e-03],
#         [-9.6693e-03,  1.1681e-02, -9.7718e-03,  ...,  1.3349e-04,
#           2.0898e-03, -9.7508e-04],
#         [-8.0026e-03, -4.4050e-03,  1.5243e-03,  ...,  1.6251e-02,
#           1.6871e-02, -1.7861e-02]])

# %%
config = OmegaConf.load(checkpoint_config_path)

# Lets start by examining our config file

print(OmegaConf.to_yaml(config))
# Out:
# data_workers: 10
# name: Walrus-wella-delta-Isotr[Space-Adapt-]-AdamW-0.0002
# automatic_setup: true
# trainer:
#   _target_: walrus.trainer.Trainer
#   max_epoch: 200
#   val_frequency: 10
#   rollout_val_frequency: 10
#   short_validation_length: 20
#   max_rollout_steps: 200
#   num_time_intervals: 5
#   enable_amp: false
#   loss_fn:
#     _target_: the_well.benchmark.metrics.MAE
#   formatter:
#     _target_: hydra.utils.get_class
#     path: walrus.data.well_to_multi_transformer.ChannelsFirstWithTimeFormatter
#   revin:
#     _target_: walrus.trainer.normalization_strat.SamplewiseRevNormalization
#     _partial_: true
#   prediction_type: delta
#   grad_acc_steps: 4
#   image_validation: true
#   video_validation: true
#   gradient_log_level: 0
#   clip_gradient: 10
#   log_interval: 200
#   loss_multiplier: 100.0
#   lr_scheduler_per_step: false
#   skip_spectral_metrics: true
# optimizer:
#   _target_: torch.optim.AdamW
#   weight_decay: 0.0001
#   eps: 1.0e-10
#   lr: 0.0002
# lr_scheduler:
#   _target_: walrus.optim.schedulers.InverseSqrtLinearWarmupSqrtCooldown
#   warmup_epochs: 10
#   cooldown_epochs: 10
#   warmup_lr_factor: 0.1
#   cooldown_lr_factor: 0.001
# model:
#   encoder:
#     _partial_: true
#     _target_: walrus.models.encoders.vstride_encoder.SpaceBagAdaptiveDVstrideEncoder
#     learned_pad: true
#     base_kernel_size1d:
#     - - 4
#       - 4
#     base_kernel_size2d:
#     - - 8
#       - 4
#     - - 8
#       - 4
#     base_kernel_size3d:
#     - - 8
#       - 4
#     - - 8
#       - 4
#     - - 8
#       - 4
#     groups: 12
#     kernel_scales_seq:
#     - - 2
#       - 2
#     - - 4
#       - 2
#     - - 4
#       - 4
#     - - 8
#       - 4
#     variable_downsample: true
#     variable_deterministic_ds: true
#     activation:
#       _partial_: true
#       _target_: torch.nn.SiLU
#   decoder:
#     _partial_: true
#     _target_: walrus.models.decoders.vstride_decoder.AdaptiveDVstrideDecoder
#     learned_pad: true
#     base_kernel_size1d:
#     - - 4
#       - 4
#     base_kernel_size2d:
#     - - 8
#       - 4
#     - - 8
#       - 4
#     base_kernel_size3d:
#     - - 8
#       - 4
#     - - 8
#       - 4
#     - - 8
#       - 4
#     groups: 12
#     activation:
#       _partial_: true
#       _target_: torch.nn.SiLU
#   processor:
#     space_mixing:
#       _partial_: true
#       _target_: walrus.models.spatial_blocks.full_attention.FullAttention
#       num_heads: 16
#       mlp_dim: null
#     time_mixing:
#       _partial_: true
#       _target_: walrus.models.temporal_blocks.axial_time_attention.AxialTimeAttention
#       num_heads: 16
#       bias_type: rel
#     channel_mixing:
#       _partial_: true
#       _target_: torch.nn.Identity
#     _partial_: true
#     _target_: walrus.models.spatiotemporal_blocks.space_time_split.SpaceTimeSplitBlock
#   norm_layer:
#     _partial_: true
#     _target_: walrus.models.shared_utils.normalization.RMSGroupNorm
#   _target_: walrus.models.IsotropicModel
#   hidden_dim: 1408
#   projection_dim: 48
#   intermediate_dim: 352
#   processor_blocks: 40
#   drop_path: 0.05
#   groups: 16
#   max_d: 3
#   static_axes: true
#   weight_tied_axes: false
#   causal_in_time: true
#   include_d:
#   - 2
#   - 3
#   override_dimensionality: 0
#   jitter_patches: true
#   gradient_checkpointing_freq: 2
#   use_periodic_fixed_jitter: true
#   input_field_drop: 0.0
# data:
#   field_index_map_override:
#     closed_boundary: 0
#     open_boundary: 1
#     bias_correction: 2
#     pressure: 3
#     velocity_x: 4
#     velocity_y: 5
#     velocity_z: 6
#     zeros_like_density: 7
#     speed_of_sound: 8
#     concentration: 9
#     D_xx: 10
#     D_xy: 11
#     D_xz: 12
#     D_yx: 13
#     D_yy: 14
#     D_yz: 15
#     D_zx: 16
#     D_zy: 17
#     D_zz: 18
#     E_xx: 19
#     E_xy: 20
#     E_xz: 21
#     E_yx: 22
#     E_yy: 23
#     E_yz: 24
#     E_zx: 25
#     E_zy: 26
#     E_zz: 27
#     density: 28
#     energy: 29
#     velocity_r: 30
#     velocity_theta: 31
#     velocity_phi: 32
#     momentum_x: 33
#     momentum_y: 34
#     momentum_z: 35
#     pressure_re: 36
#     pressure_im: 37
#     mask: 38
#     magnetic_field_x: 39
#     magnetic_field_y: 40
#     magnetic_field_z: 41
#     A: 42
#     B: 43
#     height: 44
#     internal_energy: 45
#     temperature: 46
#     electron_fraction: 47
#     entropy: 48
#     magnetic_field_log_r: 49
#     magnetic_field_theta: 50
#     magnetic_field_phi: 51
#     velocity_log_r: 52
#     buoyancy: 53
#     tracer: 54
#     log10_density: 55
#     log10_temperature: 56
#     c_zz: 57
#     C_xx: 58
#     C_xy: 59
#     C_xz: 60
#     C_yx: 61
#     C_yy: 62
#     C_yz: 63
#     C_zx: 64
#     C_zy: 65
#     C_zz: 66
#   transform:
#     train:
#       _target_: the_well.data.augmentation.RandomRotation90
#       p: 1.0
#   well_base_path: /mnt/gpuxl/polymathic/the_well/datasets/
#   wandb_data_name: well_allmain_only
#   module_parameters:
#     _target_: walrus.data.MixedWellDataModule
#     batch_size: 2
#     n_steps_input: 6
#     n_steps_output: 1
#     min_dt_stride: 1
#     max_dt_stride: 5
#     max_samples: 2000
#     well_dataset_info:
#       rayleigh_benard:
#         include_filters: []
#         exclude_filters: []
#       turbulent_radiative_layer_2D:
#         include_filters: []
#         exclude_filters: []
#       flowbench_FPO_NS_2D_512x128_harmonics:
#         include_filters: []
#         exclude_filters: []
#         path: /mnt/gpuxl/polymathic/WellFormattedExternalData/flowbench/flowbench_FPO_NS_2D_512x128_harmonics
# auto_resume: true
# folder_override: ''
# checkpoint_override: ''
# config_override: null
# validation_mode: false
# frozen_components:
# - model
# distribution:
#   distribution_type: hsdp
#   local_size: 4
# logger:
#   wandb: true
#   wandb_project_name: walrus_Training_Attempts
# checkpoint:
#   _target_: walrus.trainer.checkpoints.CheckPointer
#   save_dir: /mnt/home/polymathic/ceph/walrus_logging/runs/Walrus_ft_major_v2-wella-delta-Isotr[Space-Adapt-]-AdamW-0.0002/0/checkpoints
#   load_checkpoint_path: null
#   coalesced_checkpoint_path: null
#   save_best: true
#   checkpoint_frequency: 20
#   align_fields: true
#   load_chkpt_after_finetuning_expansion: false
# finetuning_mods: {}
# experiment_dir: /mnt/home/polymathic/ceph/walrus_logging/runs

# %%
config.data.module_parameters
# Out:
# {'_target_': 'walrus.data.MixedWellDataModule', 'batch_size': 2, 'n_steps_input': 6, 'n_steps_output': 1, 'min_dt_stride': 1, 'max_dt_stride': 5, 'max_samples': 2000, 'well_dataset_info': {'rayleigh_benard': {'include_filters': [], 'exclude_filters': []}, 'turbulent_radiative_layer_2D': {'include_filters': [], 'exclude_filters': []}, 'flowbench_FPO_NS_2D_512x128_harmonics': {'include_filters': [], 'exclude_filters': [], 'path': '/mnt/gpuxl/polymathic/WellFormattedExternalData/flowbench/flowbench_FPO_NS_2D_512x128_harmonics'}}}

# %%
well_base_path = "/Users/jarvislam/neural_pde/well_data/datasets"

# First we're going to remove non-Well data since that uses absolute paths which are likely not on your system
with open_dict(config):
    del(config.data.module_parameters.well_dataset_info.flowbench_FPO_NS_2D_512x128_harmonics)

# The dataset objects precompute a number of dataset stats on init, so this may take a little while
data_module = instantiate(config.data.module_parameters, 
                          well_base_path=well_base_path,
                          world_size=1,
                          rank=0,
                          data_workers=1, 
                          field_index_map_override=config.data.get("field_index_map_override", {}), # Use the previous field maps to avoid cycling through the data
                          prefetch_field_names=False)

# %%
field_to_index_map = data_module.train_dataset.field_to_index_map
# Retrieve the number of fields used in training
# from the mapping of field to index and incrementing by 1
total_input_fields = max(field_to_index_map.values()) + 1

# %%
field_to_index_map
# Out:
# {'closed_boundary': 0, 'open_boundary': 1, 'bias_correction': 2, 'pressure': 3, 'velocity_x': 4, 'velocity_y': 5, 'velocity_z': 6, 'zeros_like_density': 7, 'speed_of_sound': 8, 'concentration': 9, 'D_xx': 10, 'D_xy': 11, 'D_xz': 12, 'D_yx': 13, 'D_yy': 14, 'D_yz': 15, 'D_zx': 16, 'D_zy': 17, 'D_zz': 18, 'E_xx': 19, 'E_xy': 20, 'E_xz': 21, 'E_yx': 22, 'E_yy': 23, 'E_yz': 24, 'E_zx': 25, 'E_zy': 26, 'E_zz': 27, 'density': 28, 'energy': 29, 'velocity_r': 30, 'velocity_theta': 31, 'velocity_phi': 32, 'momentum_x': 33, 'momentum_y': 34, 'momentum_z': 35, 'pressure_re': 36, 'pressure_im': 37, 'mask': 38, 'magnetic_field_x': 39, 'magnetic_field_y': 40, 'magnetic_field_z': 41, 'A': 42, 'B': 43, 'height': 44, 'internal_energy': 45, 'temperature': 46, 'electron_fraction': 47, 'entropy': 48, 'magnetic_field_log_r': 49, 'magnetic_field_theta': 50, 'magnetic_field_phi': 51, 'velocity_log_r': 52, 'buoyancy': 53, 'tracer': 54, 'log10_density': 55, 'log10_temperature': 56, 'c_zz': 57, 'C_xx': 58, 'C_xy': 59, 'C_xz': 60, 'C_yx': 61, 'C_yy': 62, 'C_yz': 63, 'C_zx': 64, 'C_zy': 65, 'C_zz': 66}

# %% [markdown]
# From here, we want to use the `field_to_index_map` object to determine the dimension of the encoder. Since we're
# just using the Well data in this example, this shouldn't change from the pre-existing map, but we'll get it from the dataset
# as an example.

# %%
model: torch.nn.Module = instantiate(
    config.model,
    n_states=total_input_fields,
)
model.load_state_dict(checkpoint)

# Move to the device we want
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# Out:
# /Users/jarvislam/neural_pde/venv/lib/python3.12/site-packages/walrus/models/temporal_blocks/axial_time_attention.py:38: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   init.kaiming_uniform(
# IsotropicModel(
#   (patch_jitterer): FixedPatchJittererBoundaryPad()
#   (embed): ModuleDict(
#     (2): SpaceBagAdaptiveDVstrideEncoder(
#       (proj1): Conv3d(67, 352, kernel_size=(8, 8, 8), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): Conv3d(352, 1408, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm2): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#     )
#     (3): SpaceBagAdaptiveDVstrideEncoder(
#       (proj1): Conv3d(67, 352, kernel_size=(8, 8, 8), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): Conv3d(352, 1408, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm2): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#     )
#   )
#   (blocks): ModuleList(
#     (0): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): Identity()
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): Identity()
#       )
#       (channel_mixing): Identity()
#     )
#     (1): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.001)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.001)
#       )
#       (channel_mixing): Identity()
#     )
#     (2): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.003)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.003)
#       )
#       (channel_mixing): Identity()
#     )
#     (3): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.004)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.004)
#       )
#       (channel_mixing): Identity()
#     )
#     (4): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.005)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.005)
#       )
#       (channel_mixing): Identity()
#     )
#     (5): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.006)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.006)
#       )
#       (channel_mixing): Identity()
#     )
#     (6): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.008)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.008)
#       )
#       (channel_mixing): Identity()
#     )
#     (7): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.009)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.009)
#       )
#       (channel_mixing): Identity()
#     )
#     (8): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.010)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.010)
#       )
#       (channel_mixing): Identity()
#     )
#     (9): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.012)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.012)
#       )
#       (channel_mixing): Identity()
#     )
#     (10): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.013)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.013)
#       )
#       (channel_mixing): Identity()
#     )
#     (11): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.014)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.014)
#       )
#       (channel_mixing): Identity()
#     )
#     (12): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.015)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.015)
#       )
#       (channel_mixing): Identity()
#     )
#     (13): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.017)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.017)
#       )
#       (channel_mixing): Identity()
#     )
#     (14): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.018)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.018)
#       )
#       (channel_mixing): Identity()
#     )
#     (15): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.019)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.019)
#       )
#       (channel_mixing): Identity()
#     )
#     (16): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.021)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.021)
#       )
#       (channel_mixing): Identity()
#     )
#     (17): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.022)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.022)
#       )
#       (channel_mixing): Identity()
#     )
#     (18): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.023)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.023)
#       )
#       (channel_mixing): Identity()
#     )
#     (19): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.024)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.024)
#       )
#       (channel_mixing): Identity()
#     )
#     (20): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.026)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.026)
#       )
#       (channel_mixing): Identity()
#     )
#     (21): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.027)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.027)
#       )
#       (channel_mixing): Identity()
#     )
#     (22): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.028)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.028)
#       )
#       (channel_mixing): Identity()
#     )
#     (23): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.029)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.029)
#       )
#       (channel_mixing): Identity()
#     )
#     (24): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.031)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.031)
#       )
#       (channel_mixing): Identity()
#     )
#     (25): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.032)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.032)
#       )
#       (channel_mixing): Identity()
#     )
#     (26): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.033)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.033)
#       )
#       (channel_mixing): Identity()
#     )
#     (27): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.035)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.035)
#       )
#       (channel_mixing): Identity()
#     )
#     (28): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.036)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.036)
#       )
#       (channel_mixing): Identity()
#     )
#     (29): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.037)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.037)
#       )
#       (channel_mixing): Identity()
#     )
#     (30): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.038)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.038)
#       )
#       (channel_mixing): Identity()
#     )
#     (31): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.040)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.040)
#       )
#       (channel_mixing): Identity()
#     )
#     (32): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.041)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.041)
#       )
#       (channel_mixing): Identity()
#     )
#     (33): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.042)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.042)
#       )
#       (channel_mixing): Identity()
#     )
#     (34): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.044)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.044)
#       )
#       (channel_mixing): Identity()
#     )
#     (35): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.045)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.045)
#       )
#       (channel_mixing): Identity()
#     )
#     (36): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.046)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.046)
#       )
#       (channel_mixing): Identity()
#     )
#     (37): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.047)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.047)
#       )
#       (channel_mixing): Identity()
#     )
#     (38): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.049)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.049)
#       )
#       (channel_mixing): Identity()
#     )
#     (39): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.050)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.050)
#       )
#       (channel_mixing): Identity()
#     )
#   )
#   (debed): ModuleDict(
#     (2): AdaptiveDVstrideDecoder(
#       (proj1): ConvTranspose3d(1408, 352, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): ConvTranspose3d(352, 67, kernel_size=(8, 8, 8), stride=(1, 1, 1))
#     )
#     (3): AdaptiveDVstrideDecoder(
#       (proj1): ConvTranspose3d(1408, 352, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): ConvTranspose3d(352, 67, kernel_size=(8, 8, 8), stride=(1, 1, 1))
#     )
#   )
# )

# %% [markdown]
# Now that we have a pretrained model, let's look at how we would use it. First, we need a couple helper objects - the formatter and the normalization object. Since Walrus was trained with reversible normalization, it can be easier to implement outside of the data loader.
#
# The formatter object converts data from the Well convention format to the format ingested by Walrus.
#
# The normalization object normalizes the data before it enters the model and denormalizes the outputs.

# %%
# !pip install torch==2.5.1 torchvision==0.20.1 torchaudio==2.5.1
# Out:
# Requirement already satisfied: torch==2.5.1 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: torchvision==0.20.1 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (0.20.1)
# Requirement already satisfied: torchaudio==2.5.1 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: filelock in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (4.15.0)
# Requirement already satisfied: networkx in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (3.1.6)
# Requirement already satisfied: fsspec in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (2024.10.0)
# Requirement already satisfied: setuptools in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (81.0.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torch==2.5.1) (1.13.1)
# Requirement already satisfied: numpy in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torchvision==0.20.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from torchvision==0.20.1) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.5.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (from jinja2->torch==2.5.1) (3.0.3)

# %%
# !cd .. && pwd && python3.12 -m pip install -e .

# %%
formatter = ChannelsFirstWithTimeFormatter()
revin = instantiate(config.trainer.revin)() # This is a functools partial by default

# %% [markdown]
# Before we use the model, let's look at the structure of the data. This will give us important information for how we can use the model when we don't have Well-formatted data.

# %%
# Grab one trajectory to use as an example
dataset_index = 1 # Corresponds to acoustic_scatter_inclusions
dataset = data_module.rollout_val_datasets[dataset_index].sub_dsets[0]
metadata = dataset.metadata

data_module.data_workers = 0

trajectory_example = next(iter(data_module.rollout_val_dataloaders()[dataset_index]))

print("Metadata:", metadata)
print("Trajectory example keys:", trajectory_example.keys())
# Out:
# Metadata: WellMetadata(dataset_name='turbulent_radiative_layer_2D', n_spatial_dims=3, spatial_resolution=(128, 384, 1), scalar_names=[], constant_scalar_names=['tcool'], field_names={0: ['density', 'pressure'], 1: ['velocity_x', 'velocity_y', 'velocity_z'], 2: []}, constant_field_names={0: [], 1: [], 2: []}, boundary_condition_types=['OPEN', 'PERIODIC', 'PERIODIC'], n_files=1, n_trajectories_per_file=[1], n_steps_per_trajectory=[101], grid_type='cartesian')
# Trajectory example keys: dict_keys(['input_fields', 'output_fields', 'constant_scalars', 'boundary_conditions', 'space_grid', 'input_time_grid', 'output_time_grid', 'padded_field_mask', 'field_indices', 'metadata'])

# %% [markdown]
# The `MixedWellDataset` object outputs several important fields:
# - `input_fields` - These are time varying state variables to use as input.
# - `out_fields` - Time varying state variables that the model is expected to predict.
# - `constant_fields` - Input values that don't vary with time.
# - `boundary_conditions` - list of lists containing the properties of the borders. These are restricted to topological details "periodic", "open", and "wall"/closed. For instance, the values [[0, 0], [1, 0], [2, 2]] would indicate the first axis (x) has closed boundaries on both sides, while the second (y) has an open boundary at ($y=0$) and closed at ($y=1$). The third (z) is periodic.
# - `padded_field_mask` - When applying rotations, it can be difficult to tell which tensor-valued fields are real and which are from padding into higher dimensions. This lets us know which are which so we can evaluate only the true fields.
# - `field_indices` - This is a new object in Walrus's `MixedWellDataset` that tracks mappings from field names to indices. This tells the model what types of fields it's using at any given time.
# - `metadata` - This is a typical Well metadata object, but as this type of object can sample from multiple data sources, this is passed to make it easier to track what type of data we're working with.
#
# ```
# # Boundary condition codes
# class BoundaryCondition(Enum):
#     WALL = 0
#     OPEN = 1
#     PERIODIC = 2
# ```
#
# Now lets see how we can use the model to forecast the evolution of this field! Let's define a helper function which performs an autoregressive rollout.
#
# We want this helper to:
# - Move our data to the target device
# - Reshape the data into the format expected by Walrus
# - Rollout the model as many steps as we have reference data for, performing appropriate normalization as we go

# %%
import copy
from walrus.trainer.training import expand_mask_to_match

def rollout_model(model, revin, batch, formatter, max_rollout_steps=10, model_epsilon=1e-5, device=torch.device("cpu")):
    """Rollout the model for as many steps as we have data for.

    Simplified version of the trainer method for demo purposes.
    """
    metadata = batch["metadata"]
    print(f"[rollout] dataset={metadata.dataset_name}  input_fields={batch['input_fields'].shape}  output_fields={batch['output_fields'].shape}")

    batch = {
        k: v.to(device)
        if k not in {"metadata", "boundary_conditions"}
        else v
        for k, v in batch.items()
    }
    # Extract mask and move to device for loss eval
    if (
        "mask" in batch["metadata"].constant_field_names[0] # Assuming all metadata in batch are the same
    ):
        mask_index = batch["metadata"].constant_field_names[0].index("mask")
        mask = batch["constant_fields"][..., mask_index : mask_index + 1]
        mask = mask.to(device, dtype=torch.bool)
        print(f"[rollout] mask found at constant_field index {mask_index}, shape={mask.shape}")
    else:
        mask = None
        print(f"[rollout] no mask field")

    inputs, y_ref = formatter.process_input(
        batch,
        causal_in_time=model.causal_in_time,
        predict_delta=True,
        train=False,
    )
    print(f"[rollout] formatter -> inputs[0]={inputs[0].shape}  inputs[1]={inputs[1].shape}  y_ref={y_ref.shape}")

    # Inputs T B C H [W D], y_ref B T H [W D] C
    T_in = batch["input_fields"].shape[1]
    max_rollout_steps = max_rollout_steps + (T_in - 1)
    rollout_steps = min(y_ref.shape[1], max_rollout_steps)  # Number of timesteps in target
    train_rollout_limit = 1
    print(f"[rollout] T_in={T_in}  rollout_steps={rollout_steps}  (capped at max={max_rollout_steps})")

    y_ref = y_ref[:, :rollout_steps] # If we set a maximum number of rollout steps, just cut it off now to save memory
    # Create a moving batch of one step at a time
    moving_batch = copy.deepcopy(batch)
    y_preds = []
    # Rollout the model - Causal in time gets more predictions from the first step
    for i in range(train_rollout_limit - 1, rollout_steps):
        print(f"[rollout] step {i+1}/{rollout_steps}")
        # Don't fill causal_in_time here since that only affects y_ref
        inputs, _ = formatter.process_input(moving_batch)
        inputs = list(inputs)
        with torch.no_grad():
            normalization_stats = revin.compute_stats(
                inputs[0], metadata, epsilon=model_epsilon
            )
        # NOTE - Currently assuming only [0] (fields) needs normalization
        normalized_inputs = inputs[:]  # Shallow copy
        normalized_inputs[0] = revin.normalize_stdmean(
            normalized_inputs[0], normalization_stats
        )
        print(f"[rollout]   model input shape={normalized_inputs[0].shape}")
        y_pred = model(
            normalized_inputs[0],
            normalized_inputs[1],
            normalized_inputs[2].tolist(),
            metadata=metadata,
        )
        print(f"[rollout]   model output shape={y_pred.shape}")
        # During validation, don't maintain full inner predictions
        if model.causal_in_time:
            y_pred = y_pred[-1:]  # y_pred is T first, y_ref is not
        # In validation, we want to reconstruct predictions on original scale
        y_pred = (inputs[0][-y_pred.shape[0]:].float() 
                  + revin.denormalize_delta(y_pred, normalization_stats))  # Unnormalize delta and add to input
        y_pred = formatter.process_output(y_pred, metadata)[..., : y_ref.shape[-1]]  # Cut off constant channels
        print(f"[rollout]   y_pred after denorm+format={y_pred.shape}")

        # If we have masked fields, just move them back to zeros
        if mask is not None:
            mask_pred = expand_mask_to_match(mask, y_pred)
            y_pred.masked_fill_(mask_pred, 0)

        y_pred = y_pred.masked_fill(~batch["padded_field_mask"], 0.0)

        # If not last step, update moving batch for autoregressive prediction
        if i != rollout_steps - 1:
            moving_batch["input_fields"] = torch.cat(
                [moving_batch["input_fields"][:, 1:], y_pred[:, -1:]], dim=1
            )
        # For causal models, we get use full predictions for the first batch and
        # incremental predictions for subsequent batches - concat 1:T to y_ref for loss eval
        if model.causal_in_time and i == train_rollout_limit - 1:
            y_preds.append(y_pred)
        else:
            y_preds.append(y_pred[:, -1:])

    y_pred_out = torch.cat(y_preds, dim=1)
    print(f"[rollout] complete  y_pred_out={y_pred_out.shape}  y_ref={y_ref.shape}")
    if mask is not None:
        mask_ref = expand_mask_to_match(mask, y_ref)
        y_ref.masked_fill_(mask_ref, 0)
    return y_pred_out, y_ref

# %% [markdown]
# Now lets make our forecast!

# %%
with torch.no_grad():
    trajectory_example["padded_field_mask"] = trajectory_example["padded_field_mask"].to(device) # We're going to want this out here too
    inputs, y_ref = formatter.process_input(
        trajectory_example,
        causal_in_time=model.causal_in_time,
        predict_delta=True,
        train=False,
    )
    y_pred, y_ref = rollout_model(
        model,
        revin,
        trajectory_example,
        formatter,
        max_rollout_steps=200,
        device=device,
    )

    # Lets get some extra info so we can visualize our data effectively
    # Remove unused fields
    y_pred, y_ref = (
        y_pred[..., trajectory_example["padded_field_mask"]],
        y_ref[..., trajectory_example["padded_field_mask"]],
    )
    # Collecting names to make detailed output logs
    field_names = flatten_field_names(metadata, include_constants=False)
    used_field_names = [
        f
        for i, f in enumerate(field_names)
        if trajectory_example["padded_field_mask"][i]
    ]
# Out:
# [rollout] dataset=turbulent_radiative_layer_2D  input_fields=torch.Size([1, 6, 128, 384, 1, 5])  output_fields=torch.Size([1, 95, 128, 384, 1, 5])
# [rollout] no mask field
# [rollout] formatter -> inputs[0]=torch.Size([6, 1, 5, 128, 384, 1])  inputs[1]=torch.Size([5])  y_ref=torch.Size([1, 95, 128, 384, 1, 5])
# [rollout] T_in=6  rollout_steps=95  (capped at max=205)
# [rollout] step 1/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 2/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 3/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 4/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 5/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 6/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 7/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 8/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 9/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 10/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 11/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 12/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 13/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 14/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 15/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 16/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 17/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 18/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 19/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 20/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 21/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 22/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 23/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 24/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 25/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 26/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 27/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 28/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 29/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 30/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 31/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 32/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 33/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 34/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 35/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 36/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 37/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 38/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 39/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 40/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 41/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 42/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 43/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 44/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 45/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 46/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 47/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 48/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 49/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 50/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 51/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 52/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 53/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 54/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 55/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 56/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 57/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 58/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 59/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 60/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 61/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 62/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 63/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 64/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 65/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 66/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 67/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 68/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 69/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 70/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 71/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 72/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 73/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 74/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 75/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 76/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 77/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 78/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 79/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 80/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 81/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 82/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 83/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 84/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 85/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 86/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 87/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 88/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 89/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 90/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 91/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 92/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 93/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 94/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] step 95/95
# [rollout]   model input shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   model output shape=torch.Size([6, 1, 5, 128, 384, 1])
# [rollout]   y_pred after denorm+format=torch.Size([1, 1, 128, 384, 1, 5])
# [rollout] complete  y_pred_out=torch.Size([1, 95, 128, 384, 1, 5])  y_ref=torch.Size([1, 95, 128, 384, 1, 5])

# %%
y_pred.size()
# Out:
# torch.Size([1, 95, 128, 384, 1, 4])

# %%
# !pip install imageio-ffmpeg
# Out:
# Requirement already satisfied: imageio-ffmpeg in /Users/jarvislam/walrus/.venv/lib/python3.12/site-packages (0.6.0)

# %%
import imageio_ffmpeg
import matplotlib
matplotlib.rcParams['animation.ffmpeg_path'] = imageio_ffmpeg.get_ffmpeg_exe()

# %%
from the_well.benchmark.metrics import make_video
output_dir = "/Users/jarvislam/neural_pde/figures/"

make_video(
    y_pred[0],  # First sample only in batch
    y_ref[0],  # First sample only in batch
    metadata,
    output_dir=output_dir,
    epoch_number="ac_inclusion_example",  # Misleading parameter name, but duck typing lets it be used for naming the output. Needs upstream fix.
    field_name_overrides=used_field_names,  # Fields actually used
    size_multiplier=1.,  # 
)
# Out:
# Python(83028) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# {}

# %%
metadata.dataset_name
# Out:
# 'turbulent_radiative_layer_2D'

# %%
from IPython.display import Video

Video(f'{output_dir}/{metadata.dataset_name}/rollout_video/epochac_inclusion_example_{metadata.dataset_name}.mp4', width=640, height=360)
# Out:
# <video src="./figures//turbulent_radiative_layer_2D/rollout_video/epochac_inclusion_example_turbulent_radiative_layer_2D.mp4" controls  width="640"  height="360">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Awesome! We've made predictions with our pretrained model. Now let's look into what would happen if we needed to use the model for a downstream task and didn't want to go through the effort of first moving the data into the Well format.
#
# ## Part 2: Non-Well data
#
# Now lets see what we'd do in the case where we don't have Well structured data. The key difference here is that we'd need to define our own data transformation objects to make sure that every object in the pipeline is getting the data in the format they need it.
#
# We also need to make sure that our field_to_index_map is lined up with the new data which may include fields we haven't seen before.
#
# First let's get some extra imports from the library out of the way.

# %%
from walrus.utils.experiment_utils import align_checkpoint_with_field_to_index_map
from the_well.data.datasets import WellMetadata

# %% [markdown]
# Let's make a hypothetical dataset. This dataset has 4 fields - velocity_x, velocity_y, density, and a new, never-before-seen field "blubber". First, we'll check out the existing `field_to_index_map` to see what we can use:

# %%
field_to_index_map
# Out:
# {'closed_boundary': 0, 'open_boundary': 1, 'bias_correction': 2, 'pressure': 3, 'velocity_x': 4, 'velocity_y': 5, 'velocity_z': 6, 'zeros_like_density': 7, 'speed_of_sound': 8, 'concentration': 9, 'D_xx': 10, 'D_xy': 11, 'D_xz': 12, 'D_yx': 13, 'D_yy': 14, 'D_yz': 15, 'D_zx': 16, 'D_zy': 17, 'D_zz': 18, 'E_xx': 19, 'E_xy': 20, 'E_xz': 21, 'E_yx': 22, 'E_yy': 23, 'E_yz': 24, 'E_zx': 25, 'E_zy': 26, 'E_zz': 27, 'density': 28, 'energy': 29, 'velocity_r': 30, 'velocity_theta': 31, 'velocity_phi': 32, 'momentum_x': 33, 'momentum_y': 34, 'momentum_z': 35, 'pressure_re': 36, 'pressure_im': 37, 'mask': 38, 'magnetic_field_x': 39, 'magnetic_field_y': 40, 'magnetic_field_z': 41, 'A': 42, 'B': 43, 'height': 44, 'internal_energy': 45, 'temperature': 46, 'electron_fraction': 47, 'entropy': 48, 'magnetic_field_log_r': 49, 'magnetic_field_theta': 50, 'magnetic_field_phi': 51, 'velocity_log_r': 52, 'buoyancy': 53, 'tracer': 54, 'log10_density': 55, 'log10_temperature': 56, 'c_zz': 57, 'C_xx': 58, 'C_xy': 59, 'C_xz': 60, 'C_yx': 61, 'C_yy': 62, 'C_yz': 63, 'C_zx': 64, 'C_zy': 65, 'C_zz': 66}

# %% [markdown]
# Three of our fields are covered. Additionally, since Walrus is expecting dimensionally padded data, we'll also need to include a velocity_x which we can concatenate to the end since these are treated as sets and the order doesn't matter.
#
# So we'll be passing fields {"velocity_x": 4, "velocity_y":5, "velocity_z": 6, "density": 28, "blubber": ?????} in the order [4, 5, 28, ????. 6].
#
# The question we need to answer is: how do we deal with blubber? This is fortunately easy enough, we just need to add an extra field to this mapping dictionary and pass it appropriately.

# %%
new_field_to_index_map = copy.deepcopy(field_to_index_map)
new_field_to_index_map["blubber"] = max(field_to_index_map.values()) + 1  # New index for "blubber"

model = instantiate(
    config.model,
    n_states=max(new_field_to_index_map.values()) + 1,
)


# Use the Walrus utility to align the checkpoint
revised_model_checkpoint = align_checkpoint_with_field_to_index_map(
    checkpoint_state_dict=checkpoint,
    model_state_dict=model.state_dict(),
    checkpoint_field_to_index_map=field_to_index_map,
    model_field_to_index_map=new_field_to_index_map,
)

# Now load the aligned weights
model.load_state_dict(revised_model_checkpoint)

model.to(device)
model.eval()
# Out:
# /mnt/home/mmccabe/venvs/clean_walrus/lib/python3.11/site-packages/walrus/models/temporal_blocks/axial_time_attention.py:38: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   init.kaiming_uniform(
# IsotropicModel(
#   (patch_jitterer): FixedPatchJittererBoundaryPad()
#   (embed): ModuleDict(
#     (2): SpaceBagAdaptiveDVstrideEncoder(
#       (proj1): Conv3d(68, 352, kernel_size=(8, 8, 8), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): Conv3d(352, 1408, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm2): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#     )
#     (3): SpaceBagAdaptiveDVstrideEncoder(
#       (proj1): Conv3d(68, 352, kernel_size=(8, 8, 8), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): Conv3d(352, 1408, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm2): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#     )
#   )
#   (blocks): ModuleList(
#     (0): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): Identity()
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): Identity()
#       )
#       (channel_mixing): Identity()
#     )
#     (1): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.001)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.001)
#       )
#       (channel_mixing): Identity()
#     )
#     (2): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.003)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.003)
#       )
#       (channel_mixing): Identity()
#     )
#     (3): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.004)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.004)
#       )
#       (channel_mixing): Identity()
#     )
#     (4): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.005)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.005)
#       )
#       (channel_mixing): Identity()
#     )
#     (5): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.006)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.006)
#       )
#       (channel_mixing): Identity()
#     )
#     (6): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.008)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.008)
#       )
#       (channel_mixing): Identity()
#     )
#     (7): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.009)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.009)
#       )
#       (channel_mixing): Identity()
#     )
#     (8): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.010)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.010)
#       )
#       (channel_mixing): Identity()
#     )
#     (9): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.012)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.012)
#       )
#       (channel_mixing): Identity()
#     )
#     (10): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.013)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.013)
#       )
#       (channel_mixing): Identity()
#     )
#     (11): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.014)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.014)
#       )
#       (channel_mixing): Identity()
#     )
#     (12): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.015)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.015)
#       )
#       (channel_mixing): Identity()
#     )
#     (13): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.017)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.017)
#       )
#       (channel_mixing): Identity()
#     )
#     (14): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.018)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.018)
#       )
#       (channel_mixing): Identity()
#     )
#     (15): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.019)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.019)
#       )
#       (channel_mixing): Identity()
#     )
#     (16): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.021)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.021)
#       )
#       (channel_mixing): Identity()
#     )
#     (17): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.022)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.022)
#       )
#       (channel_mixing): Identity()
#     )
#     (18): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.023)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.023)
#       )
#       (channel_mixing): Identity()
#     )
#     (19): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.024)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.024)
#       )
#       (channel_mixing): Identity()
#     )
#     (20): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.026)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.026)
#       )
#       (channel_mixing): Identity()
#     )
#     (21): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.027)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.027)
#       )
#       (channel_mixing): Identity()
#     )
#     (22): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.028)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.028)
#       )
#       (channel_mixing): Identity()
#     )
#     (23): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.029)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.029)
#       )
#       (channel_mixing): Identity()
#     )
#     (24): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.031)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.031)
#       )
#       (channel_mixing): Identity()
#     )
#     (25): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.032)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.032)
#       )
#       (channel_mixing): Identity()
#     )
#     (26): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.033)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.033)
#       )
#       (channel_mixing): Identity()
#     )
#     (27): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.035)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.035)
#       )
#       (channel_mixing): Identity()
#     )
#     (28): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.036)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.036)
#       )
#       (channel_mixing): Identity()
#     )
#     (29): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.037)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.037)
#       )
#       (channel_mixing): Identity()
#     )
#     (30): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.038)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.038)
#       )
#       (channel_mixing): Identity()
#     )
#     (31): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.040)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.040)
#       )
#       (channel_mixing): Identity()
#     )
#     (32): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.041)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.041)
#       )
#       (channel_mixing): Identity()
#     )
#     (33): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.042)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.042)
#       )
#       (channel_mixing): Identity()
#     )
#     (34): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.044)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.044)
#       )
#       (channel_mixing): Identity()
#     )
#     (35): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.045)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.045)
#       )
#       (channel_mixing): Identity()
#     )
#     (36): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.046)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.046)
#       )
#       (channel_mixing): Identity()
#     )
#     (37): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.047)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.047)
#       )
#       (channel_mixing): Identity()
#     )
#     (38): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.049)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.049)
#       )
#       (channel_mixing): Identity()
#     )
#     (39): SpaceTimeSplitBlock(
#       (space_mixing): FullAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (fused_ff_qkv): Linear(in_features=1408, out_features=9856, bias=True)
#         (activation): SwiGLU()
#         (ff_out): Linear(in_features=2816, out_features=1408, bias=True)
#         (attn_out): Linear(in_features=1408, out_features=1408, bias=False)
#         (q_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (k_norm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rotary_emb): RotaryEmbedding()
#         (drop_path): DropPath(drop_prob=0.050)
#       )
#       (time_mixing): AxialTimeAttention(
#         (norm1): RMSGroupNorm(16, 1408, eps=1e-06, affine=True)
#         (input_head): Conv3d(1408, 4224, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (output_head): Conv3d(1408, 1408, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (qnorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (knorm): LayerNorm((88,), eps=1e-05, elementwise_affine=True)
#         (rel_pos_bias): RelativePositionBias(
#           (relative_attention_bias): Embedding(32, 16)
#         )
#         (drop_path): DropPath(drop_prob=0.050)
#       )
#       (channel_mixing): Identity()
#     )
#   )
#   (debed): ModuleDict(
#     (2): AdaptiveDVstrideDecoder(
#       (proj1): ConvTranspose3d(1408, 352, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): ConvTranspose3d(352, 68, kernel_size=(8, 8, 8), stride=(1, 1, 1))
#     )
#     (3): AdaptiveDVstrideDecoder(
#       (proj1): ConvTranspose3d(1408, 352, kernel_size=(4, 4, 4), stride=(1, 1, 1), bias=False)
#       (norm1): RMSGroupNorm(16, 352, eps=1e-06, affine=True)
#       (act): SiLU()
#       (proj2): ConvTranspose3d(352, 68, kernel_size=(8, 8, 8), stride=(1, 1, 1))
#     )
#   )
# )

# %% [markdown]
# Now we just need to pass data with the right signature. From before, we know the model is using the following fields:
# - `input_fields` - float tensor [B x T_in x H x W x D x C_var]
# - `output_fields` - float tensor [B x T_out x H x W x D x C_var]
# - `constant_fields` - Optional, float tensor[B x H x W x D x C_con]
# - `boundary_conditions` - int tensor [Bx3x2]
# - `padded_field_mask` - bool tensor [C_var]
# - `field_indices` - Int tensor [C_var + C_con]
# - `metadata` - WellMetadata - Not strictly necessary, but our functions above use this to help with logging, so we'll make one here too

# %%
B = 1
T_in = 6
T_out = 10
H = 128
W = 128
D = 1
C_var = 5  # velocity_x, velocity_y, velocity_z, density, blubber
C_con = 0  # No constant fields in this example


synthetic_trajectory_example = {
    "input_fields": torch.randn(B, T_in, H, W, D, C_var, device=device),
    "output_fields": torch.randn(B, T_out, H, W, D, C_var, device=device),
    "constant_fields": torch.randn(B, H, W, D, C_con, device=device),
    "boundary_conditions": torch.tensor([[[2, 2], [2, 2], [2, 2]] for _ in range(B)], device=device),  # Example BCs
    "padded_field_mask": torch.tensor([True, True, True, True, False], device=device),  # Last field index is padded
    "field_indices": torch.tensor([4, 5, 28, 67, 6], device=device),  # Indices for all fields
    "metadata": WellMetadata(
        dataset_name="synthetic_dataset",
        n_spatial_dims=3,
        field_names={0: ['pressure', "blubber"], 1: ['velocity_x', 'velocity_y', 'velocity_z'], 2: []},
        spatial_resolution=(128, 128, 1),
        scalar_names=[], 
        constant_field_names={0: [], 1: [], 2: []},
        constant_scalar_names=[],
        boundary_condition_types=[], # Doesn't matter
        n_files =[], # Doesn't matter
        n_trajectories_per_file=[], # Doesn't matter
        n_steps_per_trajectory=[], # Doesn't matter
    ),
}

# %%
with torch.no_grad():
    synthetic_trajectory_example["padded_field_mask"] = synthetic_trajectory_example["padded_field_mask"].to(device) # We're going to want this out here too
    inputs, y_ref = formatter.process_input(
        synthetic_trajectory_example,
        causal_in_time=model.causal_in_time,
        predict_delta=True,
        train=False,
    )
    fake_metadata = synthetic_trajectory_example["metadata"]
    y_pred, y_ref = rollout_model(
        model,
        revin,
        synthetic_trajectory_example,
        formatter,
        max_rollout_steps=200,
        device=device,
    )

    # Lets get some extra info so we can visualize our data effectively
    # Remove unused fields
    y_pred, y_ref = (
        y_pred[..., synthetic_trajectory_example["padded_field_mask"]],
        y_ref[..., synthetic_trajectory_example["padded_field_mask"]],
    )
    # Collecting names to make detailed output logs
    field_names = flatten_field_names(fake_metadata, include_constants=False)
    used_field_names = [
        f
        for i, f in enumerate(field_names)
        if synthetic_trajectory_example["padded_field_mask"][i]
    ]

# %% [markdown]
# Congratulations! Now you've used Walrus with both data in the Well format and independent data. Generally when using our training code, it's going to be much easier to use Well formatted data as it handles most of what we've just done automatically for Well formatted data. If you need some guidance on how to do that, we have an example in a second notebook.
